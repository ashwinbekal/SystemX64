# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("/content/001.csv")

# %%
data.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2011     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2011     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2011     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2011      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2011      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
selected_columns = ['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION', 'DACOITY', 'ROBBERY', 'BURGLARY', 'ARSON', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES']
cData = data[selected_columns]
cData = pd.DataFrame(cData)

# %%
cData.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  RAPE  KIDNAPPING & ABDUCTION  \
# 0  ANDHRA PRADESH       ADILABAD  2011     101    50                      46
# 1  ANDHRA PRADESH      ANANTAPUR  2011     151    23                      53
# 2  ANDHRA PRADESH       CHITTOOR  2011     101    27                      59
# 3  ANDHRA PRADESH       CUDDAPAH  2011      80    20                      25
# 4  ANDHRA PRADESH  EAST GODAVARI  2011      82    23                      49
#
#    DACOITY  ROBBERY  BURGLARY  ARSON  DOWRY DEATHS  \
# 0        9       41       198     30            16
# 1        8       16       191     69             7
# 2        4       14       237     38            14
# 3        1        4        98     23            17
# 4        4       25       437     41            12
#
#    ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                149
# 1                                                118
# ...

# %%
cData.shape
# Out:
# (9017, 16)

# %%
cData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 16 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   YEAR                                                 9017 non-null   int64
#  3   MURDER                                               9017 non-null   int64
#  4   RAPE                                                 9017 non-null   int64
#  5   KIDNAPPING & ABDUCTION                               9017 non-null   int64
#  6   DACOITY                                              9017 non-null   int64
#  7   ROBBERY                                              9017 non-null   int64
# ...

# %%
cData.describe()
# Out:
#               YEAR      MURDER         RAPE  KIDNAPPING & ABDUCTION  \
# count  9017.000000  9017.00000  9017.000000             9017.000000
# mean   2016.629034    89.28535    53.041366               79.152046
# std       3.463623   327.27503   190.741450              317.630964
# min    2011.000000     0.00000     0.000000                0.000000
# 25%    2014.000000    18.00000     8.000000               10.000000
# 50%    2017.000000    38.00000    20.000000               25.000000
# 75%    2020.000000    66.00000    41.000000               56.000000
# max    2022.000000  7601.00000  3425.000000             8878.000000
#
#            DACOITY      ROBBERY      BURGLARY        ARSON  DOWRY DEATHS  \
# count  9017.000000  9017.000000   9017.000000  9017.000000   9017.000000
# mean     13.177110    55.066430    247.829433    25.219918     20.228901
# std      56.778798   220.576876    941.233426    98.880282     96.970466
# ...

# %%
cData= cData[cData['DISTRICT'] != 'TOTAL']

# %%
cData.describe()
# Out:
#               YEAR       MURDER         RAPE  KIDNAPPING & ABDUCTION  \
# count  8609.000000  8609.000000  8609.000000             8609.000000
# mean   2016.635149    47.479150    28.523754               44.365199
# std       3.464051    46.207278    36.397612              101.491292
# min    2011.000000     0.000000     0.000000                0.000000
# 25%    2014.000000    18.000000     8.000000                9.000000
# 50%    2017.000000    37.000000    19.000000               24.000000
# 75%    2020.000000    63.000000    39.000000               52.000000
# max    2022.000000   565.000000   706.000000             3970.000000
#
#            DACOITY      ROBBERY     BURGLARY        ARSON  DOWRY DEATHS  \
# count  8609.000000  8609.000000  8609.000000  8609.000000   8609.000000
# mean      6.945057    29.588570   132.523406    13.273086     10.777558
# std      10.982196    54.373584   207.438501    30.424027     14.885081
# ...

# %%
cData.shape
# Out:
# (8609, 16)

# %%
cData.tail()
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  RAPE  KIDNAPPING & ABDUCTION  \
# 9010     DELHI UT          STF  2022       0     0                       0
# 9011     DELHI UT         WEST  2022      52    79                     454
# 9012  LAKSHADWEEP  LAKSHADWEEP  2022       0     0                       0
# 9014   PUDUCHERRY     KARAIKAL  2022       5     6                       2
# 9015   PUDUCHERRY   PUDUCHERRY  2022      24     7                      17
#
#       DACOITY  ROBBERY  BURGLARY  ARSON  DOWRY DEATHS  \
# 9010        0        0         0      0             0
# 9011        2       52       186     18            18
# 9012        0        0         3      3             0
# 9014        0        3        21      1             0
# 9015        5       13        56     20             0
#
#       ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 9010                                                  0
# 9011                                                 53
# ...

# %%
cData['STATE/UT'] = cData['STATE/UT'].astype(str)
cData['DISTRICT'] = cData['DISTRICT'].astype(str)

# %%
states_List = set()
for i in cData['STATE/UT']:
  states_List.add(i)
print(states_List)
# Out:
# {'ARUNACHAL PRADESH', 'TRIPURA', 'GOA', 'RAJASTHAN', 'MANIPUR', 'A & N ISLANDS', 'MEGHALAYA', 'KERALA', 'NAGALAND', 'JAMMU & KASHMIR', 'JHARKHAND', 'ANDHRA PRADESH', 'SIKKIM', 'CHANDIGARH', 'BIHAR', 'KARNATAKA', 'D & N HAVELI', 'PUDUCHERRY', 'HIMACHAL PRADESH', 'TAMIL NADU', 'WEST BENGAL', 'LAKSHADWEEP', 'MAHARASHTRA', 'MADHYA PRADESH', 'MIZORAM', 'HARYANA', 'UTTAR PRADESH', 'CHHATTISGARH', 'DELHI UT', 'ASSAM', 'DAMAN & DIU', 'PUNJAB', 'GUJARAT', 'ODISHA', 'UTTARAKHAND'}

# %%
district_list = set()
for i in cData['DISTRICT']:
  district_list.add(i)
len(district_list)
# Out:
# 807

# %%
genders = np.random.choice(['Male', 'Female'], size=len(cData))

cData = pd.DataFrame(cData.values, columns=cData.columns)
cData['SEX'] = genders

# %%
cData.head()
# Out:
#          STATE/UT       DISTRICT  YEAR MURDER RAPE KIDNAPPING & ABDUCTION  \
# 0  ANDHRA PRADESH       ADILABAD  2011    101   50                     46
# 1  ANDHRA PRADESH      ANANTAPUR  2011    151   23                     53
# 2  ANDHRA PRADESH       CHITTOOR  2011    101   27                     59
# 3  ANDHRA PRADESH       CUDDAPAH  2011     80   20                     25
# 4  ANDHRA PRADESH  EAST GODAVARI  2011     82   23                     49
#
#   DACOITY ROBBERY BURGLARY ARSON DOWRY DEATHS  \
# 0       9      41      198    30           16
# 1       8      16      191    69            7
# 2       4      14      237    38           14
# 3       1       4       98    23           17
# 4       4      25      437    41           12
#
#   ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                149
# 1                                                118
# 2                                                112
# ...

# %%
ages = np.random.randint(10, 61, size=len(cData))
cData = pd.DataFrame(cData.values, columns=cData.columns)
cData['AGE'] = ages
cData.head()
# Out:
#          STATE/UT       DISTRICT  YEAR MURDER RAPE KIDNAPPING & ABDUCTION  \
# 0  ANDHRA PRADESH       ADILABAD  2011    101   50                     46
# 1  ANDHRA PRADESH      ANANTAPUR  2011    151   23                     53
# 2  ANDHRA PRADESH       CHITTOOR  2011    101   27                     59
# 3  ANDHRA PRADESH       CUDDAPAH  2011     80   20                     25
# 4  ANDHRA PRADESH  EAST GODAVARI  2011     82   23                     49
#
#   DACOITY ROBBERY BURGLARY ARSON DOWRY DEATHS  \
# 0       9      41      198    30           16
# 1       8      16      191    69            7
# 2       4      14      237    38           14
# 3       1       4       98    23           17
# 4       4      25      437    41           12
#
#   ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                149
# 1                                                118
# 2                                                112
# ...

# %%
import random
cData['CRIME SEASON'] = ''
crime_seasons = ['STRIKE', 'CURFEW', 'ELECTIONS', 'FESTIVE SEASONS', 'RELIGIOUS GATHERINGS AND PILGRIMAGES']
for index, row in cData.iterrows():
    cData.at[index, 'CRIME SEASON'] = random.choice(crime_seasons)

cData.head()
# Out:
#          STATE/UT       DISTRICT  YEAR MURDER RAPE KIDNAPPING & ABDUCTION  \
# 0  ANDHRA PRADESH       ADILABAD  2011    101   50                     46
# 1  ANDHRA PRADESH      ANANTAPUR  2011    151   23                     53
# 2  ANDHRA PRADESH       CHITTOOR  2011    101   27                     59
# 3  ANDHRA PRADESH       CUDDAPAH  2011     80   20                     25
# 4  ANDHRA PRADESH  EAST GODAVARI  2011     82   23                     49
#
#   DACOITY ROBBERY BURGLARY ARSON DOWRY DEATHS  \
# 0       9      41      198    30           16
# 1       8      16      191    69            7
# 2       4      14      237    38           14
# 3       1       4       98    23           17
# 4       4      25      437    41           12
#
#   ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                149
# 1                                                118
# 2                                                112
# ...

# %%
cData['CRIME SEASON'].value_counts()
# Out:
# FESTIVE SEASONS                         1763
# RELIGIOUS GATHERINGS AND PILGRIMAGES    1748
# CURFEW                                  1711
# ELECTIONS                               1709
# STRIKE                                  1678
# Name: CRIME SEASON, dtype: int64

# %%
cData.shape
# Out:
# (8609, 19)

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
nom.geocode('Bangalore')
# Out:
# Location(Bangalore, Bengaluru, Karnataka, (12.96614, 77.58694, 0.0))

# %%
def test(crimetype, state, district, year, gender, season, age):
    state_data = cData[cData['STATE/UT'] == state]
    if state_data.empty:
        return "State not found in the dataset."

    top_districts = []
    for district in state_data['DISTRICT'].unique():
        district_data = state_data[state_data['DISTRICT'] == district]
        crime_count = district_data[crimetype].sum()
        top_districts.append((district, crime_count))

    top_districts.sort(key=lambda x: x[1], reverse=True)
    top_5_districts = top_districts[:5]

    return top_5_districts

result = test("RAPE", "ANDHRA PRADESH","ANANTAPUR", 2011, "Male", "STRIKE", 52)
print(result)
# Out:
# [('WEST GODAVARI', 1062), ('MAHABOOBNAGAR', 864), ('KARIMNAGAR', 853), ('KHAMMAM', 721), ('HYDERABAD CITY', 712)]
